# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("Hi, Mr. Younis")
print("Welcome to AI with Python!")
# Out:
# Hi, Mr. Younis
# Welcome to AI with Python!

# %%
# Variables
age = 25
print(age)

score = 3.5
print(score)

# To Find the type of the variable
type(score)

name = "Younis khan"

print (name, "is good.")

is_passed = true
# Out:
# 25
# 3.5
# Younis khan is good.
